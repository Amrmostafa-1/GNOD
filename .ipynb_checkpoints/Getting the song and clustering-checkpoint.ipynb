# %% [markdown]
# ## lab-web-scraping-single-page

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "http://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#response.content

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
artist = []
for a in soup.select(".artist"):
    artist.append(a.get_text())

# %%
#artist

# %%
title = []
for t in soup.select(".title"):
    title.append(t.get_text())

# %%
#title

# %%
top = pd.DataFrame({"Title":title,"Artist":artist})
top
# Out:
#                          Title                    Artist
# 0               Margaritaville             Jimmy Buffett
# 1                  Come Monday             Jimmy Buffett
# 2   Rich Men North of Richmond      Oliver Anthony Music
# 3                     All Star               Smash Mouth
# 4     Cheeseburger In Paradise             Jimmy Buffett
# ..                         ...                       ...
# 95     Thought You Should Know             Morgan Wallen
# 96                  Dial Drunk  Noah Kahan & Post Malone
# 97             bad idea right?            Olivia Rodrigo
# 98                      august              Taylor Swift
# 99                 Unstoppable                       Sia
#
# [100 rows x 2 columns]

# %%
# To add another column if needed
#top['Position'] = range(1, 101)
#top = top[['Position','Title','Artist']]
#top

# %%
top.index = top.index + 1
top
# Out:
#                           Title                    Artist
# 1                Margaritaville             Jimmy Buffett
# 2                   Come Monday             Jimmy Buffett
# 3    Rich Men North of Richmond      Oliver Anthony Music
# 4                      All Star               Smash Mouth
# 5      Cheeseburger In Paradise             Jimmy Buffett
# ..                          ...                       ...
# 96      Thought You Should Know             Morgan Wallen
# 97                   Dial Drunk  Noah Kahan & Post Malone
# 98              bad idea right?            Olivia Rodrigo
# 99                       august              Taylor Swift
# 100                 Unstoppable                       Sia
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Getting Another Top Songs List

# %%
# list to go through pages
iterations = range(1,6)

# %%
from time import sleep
from random import randint

# %%
# get multiple pages

pages = []

for i in iterations:
    # assemble the url:
    start_at= str(i)
    url = "https://www.poplist.de/poplist.php?site="+start_at+"&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list"
    # download html with a get request:
    response = requests.get(url)
    #response = requests.get(url, headers = {"Accept-Language": "en-US"})

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))
    print(url)
    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,4)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
# Out:
# Status code: 200
# https://www.poplist.de/poplist.php?site=1&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 4 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=2&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 4 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=3&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 4 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=4&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 2 second/s.
# Status code: 200
# https://www.poplist.de/poplist.php?site=5&var1=%20AND%20(tab_list_type.ID%20=%20466)&var4=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten%20-%20Kritiker&var5=Best-of-Lists%20from%20German%20Music%20Magazines%20-%20%20The%20500%20Best%20Songs%20of%20All%20Time&var10=Rolling%20Stone%20(2004)%20Die%20500%20besten%20Songs%20aller%20Zeiten,#list
# I will sleep for 2 second/s.

# %%
#print(BeautifulSoup(pages[0].content, "html.parser").prettify())

# %%
# Parse just the first page, for testing purposes
soup = BeautifulSoup(pages[0].content, "html.parser")

# %%
#title
#listcontainer > table > tbody > tr:nth-child(2) > td:nth-child(8) > a
#listcontainer > table > tbody > tr:nth-child(3) > td:nth-child(8) > a
#listcontainer > table > tbody > tr:nth-child(101) > td:nth-child(8) > a

#artist
#listcontainer > table > tbody > tr:nth-child(2) > td.bestlist.thick > a
#listcontainer > table > tbody > tr:nth-child(3) > td.bestlist.thick > a
#listcontainer > table > tbody > tr:nth-child(101) > td.bestlist.thick > a

# %%
#soup.select("td:nth-child(8) > a")

# %%
titles = []

for i in range(len(pages)):
    # parse all pages
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    # select only the info about the titles
    # put all titles in a list
    for j in soup.select("td:nth-child(8) > a"):
        titles.append(j.get_text())

# Checking our output:

print(len(titles))
#print(len(synopsis))
# Out:
# 500

# %%
artists = []

for i in range(len(pages)):
    # parse all pages
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    # select only the info about the artists
    # put all titles in a list
    for j in soup.select("td.bestlist.thick > a"):
        artists.append(j.get_text())


# Checking our output:


print(len(artists))
# Out:
# 500

# %%
top2 = pd.DataFrame({"Title":titles,"Artist":artists})

# %%
top2
# Out:
#                              Title              Artist
# 0             Like A Rolling Stone           Bob Dylan
# 1    (I Can’t Get No) Satisfaction  The Rolling Stones
# 2                  Good Vibrations      The Beach Boys
# 3                          Imagine         John Lennon
# 4          Smells Like Teen Spirit             Nirvana
# ..                             ...                 ...
# 495              Political Science        Randy Newman
# 496                 Desolation Row           Bob Dylan
# 497                Long Tall Sally      Little Richard
# 498         A Whiter Shade Of Pale        Procol Harum
# 499  The Times They Are A-Changin’           Bob Dylan
#
# [500 rows x 2 columns]

# %%
top2.index = top2.index + 1
top2
# Out:
#                              Title              Artist
# 1             Like A Rolling Stone           Bob Dylan
# 2    (I Can’t Get No) Satisfaction  The Rolling Stones
# 3                  Good Vibrations      The Beach Boys
# 4                          Imagine         John Lennon
# 5          Smells Like Teen Spirit             Nirvana
# ..                             ...                 ...
# 496              Political Science        Randy Newman
# 497                 Desolation Row           Bob Dylan
# 498                Long Tall Sally      Little Richard
# 499         A Whiter Shade Of Pale        Procol Harum
# 500  The Times They Are A-Changin’           Bob Dylan
#
# [500 rows x 2 columns]

# %%
top.to_csv('Top 100.csv', index=False)
top2.to_csv('Top 100_2.csv', index=False)

# %%
top_all = pd.concat([top,top2], axis=0)

# %%
top_all.to_csv('Top all.csv', index=False)

# %% [markdown]
# ## GNOD Process Step 2

# %%
# Prompt the user for a song name
song_name = input("Please enter the name of a song: ")

# Check if the input contains at least one alphabetical character and/or alphanumeric character
if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    print(f"You entered a valid song name: {song_name}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: MargaritaVille
# You entered a valid song name: MargaritaVille

# %%
# Prompt the user for a artist name
artist_name = input("Please enter the name of an artist: ")

# Check if the input contains at least one alphabetical character and/or alphanumeric character
if any(c.isalpha() for c in artist_name) and any(c.isalnum() for c in artist_name):
    print(f"You entered a valid artist name: {artist_name}")
else:
    print("Invalid input. Please enter a artist name containing letters and/or numbers.")
# Out:
# Please enter the name of an artist: x
# You entered a valid artist name: x

# %%
# In case we need to check for song and artist together

# Check if the input exists in our df
#if (song_name.lower() in top['Title'].str.lower().values) & ((artist_name.lower() in top['Artist'].str.lower().values)) :
    #print(f"{song_name} by {artist_name} exists in the data frame.")
#else:
    #print(f"{song_name} by {artist_name} does not exist in the data frame.")
# Out:
# MargaritaVille by x does not exist in the data frame.

# %%
# First to check with an if condition that it works

Check if the input exists in our df
if (song_name.lower() in top['Title'].str.lower().values):
    print(f"{song_name} exists in the data frame.")
else:
    print(f"{song_name} does not exist in the data frame.")

# %% [markdown]
# ## Combining the previous parts in one code

# %% [markdown]
# Matching the song to our df and recommending another song from the same df

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = top[(top['Title'].str.lower() == song_name)]

    if not matching_song.empty:
        print(f"The song '{matching_song['Title'].values[0]}' by {matching_song['Artist'].values[0]} matches your input.")

        recommended_song = top[top['Title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['Title'].values[0]}' by {recommended_song['Artist'].values[0]}")
    else:
        print(f"No recommendations found for the song: {song_name}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: MargaritaVille
# The song 'Margaritaville' by Jimmy Buffett matches your input.
# Here's a recommended song: 'Brown Eyed Girl (Live)' by Jimmy Buffett

# %% [markdown]
# Another version where we can recommend songs from another df if there is no match to our df but it doesn't have to match the second df

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = top[(top['Title'].str.lower() == song_name)]
    matching_song2 = top2[(top2['Title'].str.lower() == song_name)]
    if not matching_song.empty:
        print(f"The song '{matching_song['Title'].values[0]}' by {matching_song['Artist'].values[0]} matches your input.")

        recommended_song = top[top['Title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['Title'].values[0]}' by {recommended_song['Artist'].values[0]}")
    else:
        other_song = other_song = top2.sample(1)
        print(f"Here's another song that might be interesting: '{other_song['Title'].values[0]}' by {other_song['Artist'].values[0]}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: x
# Here's another song that might be interesting: 'Sympathy For The Devil' by The Rolling Stones

# %% [markdown]
# Another version where we can recommend songs from another df if there is no match to our df but it has a match to another df

# %%
song_name = input("Please enter the name of a song: ")

if any(c.isalpha() for c in song_name) and any(c.isalnum() for c in song_name):
    song_name = song_name.lower()

    matching_song = top[(top['Title'].str.lower() == song_name)]
    matching_song2 = top2[(top2['Title'].str.lower() == song_name)]
    if not matching_song.empty:
        print(f"The song '{matching_song['Title'].values[0]}' by {matching_song['Artist'].values[0]} matches your input.")

        recommended_song = top[top['Title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song['Title'].values[0]}' by {recommended_song['Artist'].values[0]}")
        
    elif not matching_song2.empty:
        print(f"The song '{matching_song2['Title'].values[0]}' by {matching_song2['Artist'].values[0]} matches your input.")

        recommended_song2 = top2[top2['Title'].str.lower() != song_name].sample(1)
        print(f"Here's a recommended song: '{recommended_song2['Title'].values[0]}' by {recommended_song2['Artist'].values[0]}")

    
    else:
        print(f"No recommendations found for the song: {song_name}")
else:
    print("Invalid input. Please enter a song name containing letters and/or numbers.")
# Out:
# Please enter the name of a song: Like A Rolling Stone
# The song 'Like A Rolling Stone' by  Bob Dylan matches your input.
# Here's a recommended song: 'See Emily Play' by  Pink Floyd

# %% [markdown]
# ## Spotify API, getting songs for recommendation

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize

# %%
string = secrets_file.read()

# %%
secrets_file = open("secrets.txt","r")

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# ### Top 10000 playlist

# %%
playlist1 = sp.user_playlist_tracks("spotify", "6sx8rpqIE3R9sfGSb8Udxy")

# %%
playlist["total"]
# Out:
# 10000

# %%
len(playlist["items"])
# Out:
# 100

# %%
from random import randint
from time import sleep

# %% [markdown]
# #### Extract all the items

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify", playlist_id)
    tracks = results['items']
    count = 0  # Initialize count before the loop
    while results['next'] is not None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep_time = randint(1, 3000) / 1000  # Calculate sleep time
        sleep(sleep_time)  # respectful nap
        count += 1  # Increment count
        print(f"{count}, slept for {sleep_time} seconds")
    return tracks

# %%
all_tracks = get_playlist_tracks("6sx8rpqIE3R9sfGSb8Udxy")
len(all_tracks)
# Out:
# 1, slept for 1.239 seconds
# 2, slept for 1.618 seconds
# 3, slept for 0.123 seconds
# 4, slept for 1.926 seconds
# 5, slept for 1.436 seconds
# 6, slept for 1.094 seconds
# 7, slept for 1.124 seconds
# 8, slept for 2.784 seconds
# 9, slept for 2.975 seconds
# 10, slept for 2.62 seconds
# 11, slept for 2.647 seconds
# 12, slept for 2.577 seconds
# 13, slept for 2.473 seconds
# 14, slept for 1.468 seconds
# 15, slept for 1.072 seconds
# 16, slept for 1.72 seconds
# 17, slept for 1.858 seconds
# 18, slept for 2.006 seconds
# 19, slept for 2.471 seconds
# 20, slept for 2.721 seconds
# 21, slept for 0.822 seconds
# 22, slept for 0.452 seconds
# 23, slept for 2.425 seconds
# 24, slept for 2.271 seconds
# 25, slept for 2.425 seconds
# 26, slept for 0.299 seconds
# 27, slept for 0.415 seconds
# 28, slept for 2.502 seconds
# 29, slept for 0.302 seconds
# 30, slept for 2.03 seconds
# 31, slept for 2.646 seconds
# 32, slept for 0.343 seconds
# 33, slept for 0.92 seconds
# 34, slept for 0.209 seconds
# 35, slept for 0.399 seconds
# 36, slept for 1.466 seconds
# 37, slept for 2.738 seconds
# 38, slept for 2.787 seconds
# 39, slept for 0.668 seconds
# 40, slept for 0.009 seconds
# 41, slept for 2.324 seconds
# 42, slept for 1.384 seconds
# 43, slept for 2.709 seconds
# 44, slept for 2.557 seconds
# 45, slept for 2.404 seconds
# 46, slept for 2.062 seconds
# 47, slept for 0.174 seconds
# 48, slept for 2.595 seconds
# 49, slept for 0.392 seconds
# 50, slept for 0.512 seconds
# 51, slept for 0.411 seconds
# 52, slept for 0.166 seconds
# 53, slept for 2.668 seconds
# 54, slept for 0.843 seconds
# 55, slept for 0.049 seconds
# 56, slept for 1.969 seconds
# 57, slept for 1.698 seconds
# 58, slept for 2.695 seconds
# 59, slept for 1.259 seconds
# 60, slept for 1.089 seconds
# 61, slept for 0.129 seconds
# 62, slept for 0.783 seconds
# 63, slept for 0.896 seconds
# 64, slept for 1.109 seconds
# 65, slept for 0.133 seconds
# 66, slept for 2.379 seconds
# 67, slept for 1.493 seconds
# 68, slept for 2.212 seconds
# 69, slept for 2.782 seconds
# 70, slept for 0.688 seconds
# 71, slept for 2.509 seconds
# 72, slept for 2.63 seconds
# 73, slept for 1.438 seconds
# 74, slept for 2.241 seconds
# 75, slept for 1.642 seconds
# 76, slept for 1.506 seconds
# 77, slept for 0.755 seconds
# 78, slept for 2.557 seconds
# 79, slept for 1.181 seconds
# 80, slept for 2.224 seconds
# 81, slept for 1.779 seconds
# 82, slept for 1.239 seconds
# 83, slept for 0.214 seconds
# 84, slept for 1.979 seconds
# 85, slept for 0.646 seconds
# 86, slept for 2.814 seconds
# 87, slept for 0.412 seconds
# 88, slept for 1.996 seconds
# 89, slept for 1.125 seconds
# 90, slept for 2.639 seconds
# 91, slept for 2.726 seconds
# 92, slept for 1.358 seconds
# 93, slept for 0.512 seconds
# 94, slept for 0.849 seconds
# 95, slept for 2.016 seconds
# 96, slept for 1.098 seconds
# 97, slept for 2.885 seconds
# 98, slept for 0.761 seconds
# 99, slept for 0.209 seconds
# 10000

# %% [markdown]
# #### Flatten the data

# %%
tracks1 = json_normalize(all_tracks)

# %%
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                  track.id track.is_local  \
# 0  4u7EnebtmKWzUH433cf5Qv          False
# 1  21cp8L9Pei4AgysZVihjSv          False
# 2  2g7gviEeJr6pyxO7G35EWQ          False
# 3  6L5BZEcZmD6RBJnimzlyKr          False
# 4  3gE5067onHssnwibln70ef          False
#
#                                       track.name track.popularity  \
# 0            Bohemian Rhapsody - Remastered 2011               83
# 1                                  Child in Time               56
# 2                Paradise By the Dashboard Light               70
# 3  Nights In White Satin - Single Version / Mono               68
# 4                                 Rain And Tears                0
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/dc92880be279b619...        True
# 2  https://p.scdn.co/mp3-preview/4288d070a0b94c89...        True
# 3                                               None        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                 11      track  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1                  5      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2                  6      track  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3                 16      track  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4                  5      track  spotify:track:3gE5067onHssnwibln70ef
#
#   video_thumbnail.url
# 0                None
# 1                None
# 2                None
# 3                None
# 4                None
#
# [5 rows x 40 columns]

# %% [markdown]
# #### make the list of dictionary just a dictionary to be easier to deal with

# %%
def list_to_dict(x):
    return {i: x[i] for i in range(len(x))}

tracks1['artist_dict'] = tracks1['track.artists'].apply(list_to_dict)
tracks1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ... track.is_local  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...          False
#
#                                       track.name track.popularity  \
# 0            Bohemian Rhapsody - Remastered 2011               83
# 1                                  Child in Time               56
# 2                Paradise By the Dashboard Light               70
# 3  Nights In White Satin - Single Version / Mono               68
# 4                                 Rain And Tears                0
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1  https://p.scdn.co/mp3-preview/dc92880be279b619...        True
# 2  https://p.scdn.co/mp3-preview/4288d070a0b94c89...        True
# 3                                               None        True
# 4                                               None        True
#
#   track.track_number track.type                             track.uri  \
# 0                 11      track  spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1                  5      track  spotify:track:21cp8L9Pei4AgysZVihjSv
# 2                  6      track  spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3                 16      track  spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4                  5      track  spotify:track:3gE5067onHssnwibln70ef
#
#    video_thumbnail.url                                        artist_dict
# 0                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 1                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 2                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 3                 None  {0: {'external_urls': {'spotify': 'https://ope...
# 4                 None  {0: {'external_urls': {'spotify': 'https://ope...
#
# [5 rows x 41 columns]

# %%
tracks1['artist_dict'][0]
# Out:
# {0: {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dfeR4HaWDbWqFHLkxsg1d'},
#   'href': 'https://api.spotify.com/v1/artists/1dfeR4HaWDbWqFHLkxsg1d',
#   'id': '1dfeR4HaWDbWqFHLkxsg1d',
#   'name': 'Queen',
#   'type': 'artist',
#   'uri': 'spotify:artist:1dfeR4HaWDbWqFHLkxsg1d'}}

# %% [markdown]
# #### Convert this dictionary into a df which is inside a new column in the main df

# %%
def expand_list_dict(row):
    df = pd.DataFrame.from_dict(row['artist_dict'], orient='index')
    df['song_id'] = row['track.id']
    return df

tracks1['artists_dfs'] = tracks1.apply(expand_list_dict, axis=1)
tracks1['artists_dfs'][0]
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
#
#     name    type                                    uri  \
# 0  Queen  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
#
#                   song_id
# 0  4u7EnebtmKWzUH433cf5Qv

# %% [markdown]
# #### Extract it into a new df

# %%
artist_df = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])
for mini_df in tracks1['artists_dfs']:
    artist_df = pd.concat([artist_df, mini_df], axis=0)
    
artist_df
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/1...
# 0   {'spotify': 'https://open.spotify.com/artist/5...
# 0   {'spotify': 'https://open.spotify.com/artist/7...
# 0   {'spotify': 'https://open.spotify.com/artist/5...
# 0   {'spotify': 'https://open.spotify.com/artist/2...
# ..                                                ...
# 0   {'spotify': 'https://open.spotify.com/artist/7...
# 0   {'spotify': 'https://open.spotify.com/artist/6...
# 0   {'spotify': 'https://open.spotify.com/artist/1...
# 0   {'spotify': 'https://open.spotify.com/artist/2...
# 0   {'spotify': 'https://open.spotify.com/artist/2...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
# 0   https://api.spotify.com/v1/artists/568ZhdwyaiC...  568ZhdwyaiCyOGJRtNYhWf
# 0   https://api.spotify.com/v1/artists/7dnB1wSxbYa...  7dnB1wSxbYa8CejeVg98hz
# 0   https://api.spotify.com/v1/artists/5BcZ22XONcR...  5BcZ22XONcRoLhTbZRuME1
# 0   https://api.spotify.com/v1/artists/2XhhAWeUOlr...  2XhhAWeUOlrZnGOB7aKEI8
# ..                                                ...                     ...
# 0   https://api.spotify.com/v1/artists/7fZiIcfYlK7...  7fZiIcfYlK7sJbKpZLZSUh
# 0   https://api.spotify.com/v1/artists/69lJC8BEOzU...  69lJC8BEOzUVBj9FCxB8H5
# 0   https://api.spotify.com/v1/artists/1enLi8njBlk...  1enLi8njBlk1YlDg44MtJm
# 0   https://api.spotify.com/v1/artists/2daanolQiq5...  2daanolQiq5mJ71mbCtlR3
# 0   https://api.spotify.com/v1/artists/2BLpGstUHxD...  2BLpGstUHxDc6vHfBEiaXm
#
#                   name    type                                    uri  \
# 0                Queen  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 0          Deep Purple  artist  spotify:artist:568ZhdwyaiCyOGJRtNYhWf
# 0            Meat Loaf  artist  spotify:artist:7dnB1wSxbYa8CejeVg98hz
# 0      The Moody Blues  artist  spotify:artist:5BcZ22XONcRoLhTbZRuME1
# 0    Aphrodite's Child  artist  spotify:artist:2XhhAWeUOlrZnGOB7aKEI8
# ..                 ...     ...                                    ...
# 0           Gerard Cox  artist  spotify:artist:7fZiIcfYlK7sJbKpZLZSUh
# 0   The Rockin' Rebels  artist  spotify:artist:69lJC8BEOzUVBj9FCxB8H5
# 0        Allan Sherman  artist  spotify:artist:1enLi8njBlk1YlDg44MtJm
# 0        Corry Brokken  artist  spotify:artist:2daanolQiq5mJ71mbCtlR3
# 0             The Move  artist  spotify:artist:2BLpGstUHxDc6vHfBEiaXm
#
#                    song_id
# 0   4u7EnebtmKWzUH433cf5Qv
# 0   21cp8L9Pei4AgysZVihjSv
# 0   2g7gviEeJr6pyxO7G35EWQ
# 0   6L5BZEcZmD6RBJnimzlyKr
# 0   3gE5067onHssnwibln70ef
# ..                     ...
# 0   0AGiqUn8iyZ11bxpMxmHTD
# 0   34lwJlwglfNPSbNdbnULGy
# 0   3NW6Y1B6fL5JFMEuGfGu9Z
# 0   5NnbYL9AhZy392j3nMIeZ1
# 0   4JnvjvTknWiV6ym7nmXc7y
#
# [10622 rows x 7 columns]

# %% [markdown]
# #### Merge both df

# %%
df_merged1 = pd.merge(left=tracks1,
                    right=artist_df,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2018-12-04T20:49:14Z     False          None
# 1  2018-12-04T20:49:40Z     False          None
# 2  2018-12-04T20:50:06Z     False          None
# 3  2018-12-04T20:50:32Z     False          None
# 4  2018-12-04T20:51:00Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/q.c.m.olsthoorn
# 1  https://open.spotify.com/user/q.c.m.olsthoorn
# 2  https://open.spotify.com/user/q.c.m.olsthoorn
# 3  https://open.spotify.com/user/q.c.m.olsthoorn
# 4  https://open.spotify.com/user/q.c.m.olsthoorn
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 1  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 2  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 3  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
# 4  https://api.spotify.com/v1/users/q.c.m.olsthoorn  q.c.m.olsthoorn
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:q.c.m.olsthoorn                  album
# 1          user  spotify:user:q.c.m.olsthoorn            compilation
# 2          user  spotify:user:q.c.m.olsthoorn                  album
# 3          user  spotify:user:q.c.m.olsthoorn                  album
# 4          user  spotify:user:q.c.m.olsthoorn            compilation
#
#                                  track.album.artists  ... video_thumbnail.url  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...                None
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...                None
#
#                                          artist_dict  \
# 0  {0: {'external_urls': {'spotify': 'https://ope...
# 1  {0: {'external_urls': {'spotify': 'https://ope...
# 2  {0: {'external_urls': {'spotify': 'https://ope...
# 3  {0: {'external_urls': {'spotify': 'https://ope...
# 4  {0: {'external_urls': {'spotify': 'https://ope...
#
#                                          artists_dfs  \
# 0                                         externa...
# 1                                         externa...
# 2                                         externa...
# 3                                         externa...
# 4                                         externa...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/5...
# 2  {'spotify': 'https://open.spotify.com/artist/7...
# 3  {'spotify': 'https://open.spotify.com/artist/5...
# 4  {'spotify': 'https://open.spotify.com/artist/2...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1dfeR4HaWDb...  1dfeR4HaWDbWqFHLkxsg1d
# 1  https://api.spotify.com/v1/artists/568ZhdwyaiC...  568ZhdwyaiCyOGJRtNYhWf
# 2  https://api.spotify.com/v1/artists/7dnB1wSxbYa...  7dnB1wSxbYa8CejeVg98hz
# 3  https://api.spotify.com/v1/artists/5BcZ22XONcR...  5BcZ22XONcRoLhTbZRuME1
# 4  https://api.spotify.com/v1/artists/2XhhAWeUOlr...  2XhhAWeUOlrZnGOB7aKEI8
#
#                 name    type                                    uri  \
# 0              Queen  artist  spotify:artist:1dfeR4HaWDbWqFHLkxsg1d
# 1        Deep Purple  artist  spotify:artist:568ZhdwyaiCyOGJRtNYhWf
# 2          Meat Loaf  artist  spotify:artist:7dnB1wSxbYa8CejeVg98hz
# 3    The Moody Blues  artist  spotify:artist:5BcZ22XONcRoLhTbZRuME1
# 4  Aphrodite's Child  artist  spotify:artist:2XhhAWeUOlrZnGOB7aKEI8
#
#                   song_id
# 0  4u7EnebtmKWzUH433cf5Qv
# 1  21cp8L9Pei4AgysZVihjSv
# 2  2g7gviEeJr6pyxO7G35EWQ
# 3  6L5BZEcZmD6RBJnimzlyKr
# 4  3gE5067onHssnwibln70ef
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Choose only the columns we're intrested in

# %%
df_final1 = df_merged1[['track.name', 'name', 'song_id']]
df_final1
# Out:
#                                               track.name                name  \
# 0                    Bohemian Rhapsody - Remastered 2011               Queen
# 1                                          Child in Time         Deep Purple
# 2                        Paradise By the Dashboard Light           Meat Loaf
# 3          Nights In White Satin - Single Version / Mono     The Moody Blues
# 4                                         Rain And Tears   Aphrodite's Child
# ...                                                  ...                 ...
# 10639  Zo'n Lekkere Strakke Blonde Meid Op 'n Racefie...          Gerard Cox
# 10640                                       Wild Weekend  The Rockin' Rebels
# 10641                          Hello Mother Hello Father       Allan Sherman
# 10642                                             Milord       Corry Brokken
# 10643                  Do Ya - Single Version;Remastered            The Move
#
#                       song_id
# 0      4u7EnebtmKWzUH433cf5Qv
# 1      21cp8L9Pei4AgysZVihjSv
# 2      2g7gviEeJr6pyxO7G35EWQ
# 3      6L5BZEcZmD6RBJnimzlyKr
# 4      3gE5067onHssnwibln70ef
# ...                       ...
# 10639  0AGiqUn8iyZ11bxpMxmHTD
# 10640  34lwJlwglfNPSbNdbnULGy
# 10641  3NW6Y1B6fL5JFMEuGfGu9Z
# 10642  5NnbYL9AhZy392j3nMIeZ1
# 10643  4JnvjvTknWiV6ym7nmXc7y
#
# [10644 rows x 3 columns]

# %% [markdown]
# ### Get features of the songs
# https://developer.spotify.com/documentation/web-api/reference/get-audio-features

# %% [markdown]
# #### Get the features in chunks of 100 as spotify has a limit of 100 per request

# %%
chunks = [(i, i+100) for i in range(0, len(df_final1), 100)]
audio_features_list = []
count = 0
for chunk in chunks:
    id_list100 = df_final1['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep_time = (randint(1,3000)/1000)
    sleep(sleep_time)  # respectful nap
    count += 1  # Increment count
    print(f"{count}, slept for {sleep_time} seconds")
len(audio_features_list)
# Out:
# 10644

# %% [markdown]
# #### Flatten the feautres into a df

# %%
audio_features_df = json_normalize(audio_features_list)

# %% [markdown]
# #### Drop the duplicate song IDs to prevent assigning duplicates to the artists

# %%
audio_features_df.drop_duplicates(inplace=True)

# %%
df_w_audio_ft = pd.merge(left=df_final1,
                        right=audio_features_df,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
df_w_audio_ft.head()
# Out:
#                                               track.name                name  \
# 0                    Bohemian Rhapsody - Remastered 2011               Queen
# 1                                          Child in Time         Deep Purple
# 2                        Paradise By the Dashboard Light           Meat Loaf
# 3          Nights In White Satin - Single Version / Mono     The Moody Blues
# 4                                         Rain And Tears   Aphrodite's Child
# ...                                                  ...                 ...
# 10639  Zo'n Lekkere Strakke Blonde Meid Op 'n Racefie...          Gerard Cox
# 10640                                       Wild Weekend  The Rockin' Rebels
# 10641                          Hello Mother Hello Father       Allan Sherman
# 10642                                             Milord       Corry Brokken
# 10643                  Do Ya - Single Version;Remastered            The Move
#
#                       song_id  danceability  energy  key  loudness  mode  \
# 0      4u7EnebtmKWzUH433cf5Qv         0.414   0.404    0    -9.928     0
# 1      21cp8L9Pei4AgysZVihjSv         0.331   0.340    9   -14.784     0
# 2      2g7gviEeJr6pyxO7G35EWQ         0.326   0.872    2    -7.602     1
# 3      6L5BZEcZmD6RBJnimzlyKr         0.195   0.483    4    -4.991     0
# 4      3gE5067onHssnwibln70ef         0.306   0.426    2   -10.943     0
# ...                       ...           ...     ...  ...       ...   ...
# 10639  0AGiqUn8iyZ11bxpMxmHTD         0.637   0.790   10    -8.397     1
# 10640  34lwJlwglfNPSbNdbnULGy         0.582   0.711    7    -6.828     1
# 10641  3NW6Y1B6fL5JFMEuGfGu9Z         0.591   0.337    9   -13.186     1
# 10642  5NnbYL9AhZy392j3nMIeZ1         0.435   0.288    8   -10.553     1
# 10643  4JnvjvTknWiV6ym7nmXc7y         0.535   0.749    2    -6.744     1
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.0499       0.27100  ...    0.3000    0.224   71.105
# 1           0.0369       0.31300  ...    0.2340    0.365  126.672
# 2           0.1220       0.21400  ...    0.4610    0.492  173.381
# 3           0.0300       0.46500  ...    0.0686    0.173   84.710
# 4           0.0297       0.15900  ...    0.0867    0.326   73.220
# ...            ...           ...  ...       ...      ...      ...
# 10639       0.0553       0.43700  ...    0.3990    0.907  119.544
# 10640       0.0341       0.80500  ...    0.1180    0.825  126.412
# 10641       0.1940       0.87500  ...    0.6400    0.729  120.195
# 10642       0.0480       0.86600  ...    0.3440    0.348  102.541
# 10643       0.0675       0.00384  ...    0.0577    0.799  119.270
#
#                  type                      id  \
# 0      audio_features  4u7EnebtmKWzUH433cf5Qv
# 1      audio_features  21cp8L9Pei4AgysZVihjSv
# 2      audio_features  2g7gviEeJr6pyxO7G35EWQ
# 3      audio_features  6L5BZEcZmD6RBJnimzlyKr
# 4      audio_features  3gE5067onHssnwibln70ef
# ...               ...                     ...
# 10639  audio_features  0AGiqUn8iyZ11bxpMxmHTD
# 10640  audio_features  34lwJlwglfNPSbNdbnULGy
# 10641  audio_features  3NW6Y1B6fL5JFMEuGfGu9Z
# 10642  audio_features  5NnbYL9AhZy392j3nMIeZ1
# 10643  audio_features  4JnvjvTknWiV6ym7nmXc7y
#
#                                         uri  \
# 0      spotify:track:4u7EnebtmKWzUH433cf5Qv
# 1      spotify:track:21cp8L9Pei4AgysZVihjSv
# 2      spotify:track:2g7gviEeJr6pyxO7G35EWQ
# 3      spotify:track:6L5BZEcZmD6RBJnimzlyKr
# 4      spotify:track:3gE5067onHssnwibln70ef
# ...                                     ...
# 10639  spotify:track:0AGiqUn8iyZ11bxpMxmHTD
# 10640  spotify:track:34lwJlwglfNPSbNdbnULGy
# 10641  spotify:track:3NW6Y1B6fL5JFMEuGfGu9Z
# 10642  spotify:track:5NnbYL9AhZy392j3nMIeZ1
# 10643  spotify:track:4JnvjvTknWiV6ym7nmXc7y
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/4u7EnebtmKWz...
# 1      https://api.spotify.com/v1/tracks/21cp8L9Pei4A...
# 2      https://api.spotify.com/v1/tracks/2g7gviEeJr6p...
# 3      https://api.spotify.com/v1/tracks/6L5BZEcZmD6R...
# 4      https://api.spotify.com/v1/tracks/3gE5067onHss...
# ...                                                  ...
# 10639  https://api.spotify.com/v1/tracks/0AGiqUn8iyZ1...
# 10640  https://api.spotify.com/v1/tracks/34lwJlwglfNP...
# 10641  https://api.spotify.com/v1/tracks/3NW6Y1B6fL5J...
# 10642  https://api.spotify.com/v1/tracks/5NnbYL9AhZy3...
# 10643  https://api.spotify.com/v1/tracks/4JnvjvTknWiV...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/4u7E...      354320
# 1      https://api.spotify.com/v1/audio-analysis/21cp...      619267
# 2      https://api.spotify.com/v1/audio-analysis/2g7g...      508333
# 3      https://api.spotify.com/v1/audio-analysis/6L5B...      269107
# 4      https://api.spotify.com/v1/audio-analysis/3gE5...      191493
# ...                                                  ...         ...
# 10639  https://api.spotify.com/v1/audio-analysis/0AGi...      208133
# 10640  https://api.spotify.com/v1/audio-analysis/34lw...      137693
# 10641  https://api.spotify.com/v1/audio-analysis/3NW6...      162075
# 10642  https://api.spotify.com/v1/audio-analysis/5Nnb...      209520
# 10643  https://api.spotify.com/v1/audio-analysis/4Jnv...      196200
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 10639               4
# 10640               4
# 10641               4
# 10642               5
# 10643               4
#
# [10644 rows x 21 columns]

# %%
df_w_audio_ft.to_csv('df_w_audio_ft.csv', index=False)

# %%
#df_w_audio_ft.isna().sum()

# %% [markdown]
# ## Clustering

# %% [markdown]
# #### Adding new df from kaggle
# https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset

# %%
df2 = pd.read_csv("dataset.csv")
df2.shape
# Out:
# (114000, 21)

# %%
df2.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Adjusting the columns from both df to match, to be able to concat them

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df_w_audio_ft.columns
# Out:
# Index(['track.name', 'name', 'song_id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df2 = df2[['track_id', 'artists','track_name',
       'duration_ms','danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
#df2

# %%
df1 = df_w_audio_ft[['track.name', 'name', 'song_id', 'danceability', 'energy', 'key',
       'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
       'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']]

# %%
#df1

# %%
df1.rename(columns = {'track.name':'track_name', 'name': 'artists', 'song_id':'track_id' }, inplace = True)
# Out:
# /var/folders/q2/_chm3qg94gz5l7r736h39n040000gn/T/ipykernel_11472/1070512782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns = {'track.name':'track_name', 'name': 'artists', 'song_id':'track_id' }, inplace = True)

# %%
df2.columns
# Out:
# Index(['track_id', 'artists', 'track_name', 'duration_ms', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['track_name', 'artists', 'track_id', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df1 =df1[['track_id', 'artists', 'track_name', 'duration_ms', 'danceability',
       'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']]

# %%
songs_full = pd.concat([df1, df2], axis=0)

# %%
songs_full.isna().sum()
# Out:
# track_id            0
# artists             1
# track_name          1
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
songs_full = songs_full.dropna()

# %% [markdown]
# ### Start of the clustering

# %%
X_ft = songs_full.select_dtypes(include=['number'])
X_ft
# Out:
#         duration_ms  danceability  energy  key  loudness  mode  speechiness  \
# 0            354320         0.414   0.404    0    -9.928     0       0.0499
# 1            619267         0.331   0.340    9   -14.784     0       0.0369
# 2            508333         0.326   0.872    2    -7.602     1       0.1220
# 3            269107         0.195   0.483    4    -4.991     0       0.0300
# 4            191493         0.306   0.426    2   -10.943     0       0.0297
# ...             ...           ...     ...  ...       ...   ...          ...
# 113995       384999         0.172   0.235    5   -16.393     1       0.0422
# 113996       385000         0.174   0.117    0   -18.318     0       0.0401
# 113997       271466         0.629   0.329    0   -10.895     0       0.0420
# 113998       283893         0.587   0.506    7   -10.889     1       0.0297
# 113999       241826         0.526   0.487    1   -10.204     0       0.0725
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 0              0.271             0.000    0.3000   0.2240   71.105
# 1              0.313             0.607    0.2340   0.3650  126.672
# 2              0.214             0.000    0.4610   0.4920  173.381
# 3              0.465             0.497    0.0686   0.1730   84.710
# 4              0.159             0.000    0.0867   0.3260   73.220
# ...              ...               ...       ...      ...      ...
# 113995         0.640             0.928    0.0863   0.0339  125.995
# 113996         0.994             0.976    0.1050   0.0350   85.239
# 113997         0.867             0.000    0.0839   0.7430  132.378
# 113998         0.381             0.000    0.2700   0.4130  135.960
# 113999         0.681             0.000    0.0893   0.7080   79.198
#
#         time_signature
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    4
# ...                ...
# 113995               5
# 113996               4
# 113997               4
# 113998               4
# 113999               4
#
# [124643 rows x 13 columns]

# %% [markdown]
# ### Normalize the features using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
X_prep = StandardScaler().fit_transform(X_ft)

# %%
import pickle
scaler = StandardScaler().fit(X_ft)
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
from sklearn.cluster import KMeans
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,n_init='auto',
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score

# %%
K = range(5, 10)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k, n_init=10,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))

# %matplotlib inline
plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[169], line 8
#       5     kmeans = KMeans(n_clusters=k, n_init=10,
#       6                     random_state=1234)
#       7     kmeans.fit(X_prep)
# ----> 8     silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#      11 plt.figure(figsize=(16,8))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_unsupervised.py:117, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115     else:
#     116         X, labels = X[indices], labels[indices]
# --> 117 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_unsupervised.py:237, in silhouette_samples(X, labels, metric, **kwds)
#     233 kwds["metric"] = metric
#     234 reduce_func = functools.partial(
#     235     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     236 )
# --> 237 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     238 intra_clust_dists, inter_clust_dists = results
#     239 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/pairwise.py:1876, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1874 if reduce_func is not None:
#    1875     chunk_size = D_chunk.shape[0]
# -> 1876     D_chunk = reduce_func(D_chunk, sl.start)
#    1877     _check_chunk_size(D_chunk, chunk_size)
#    1878 yield D_chunk
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/cluster/_unsupervised.py:137, in _silhouette_reduce(D_chunk, start, labels, label_freqs)
#     135 clust_dists = np.zeros((len(D_chunk), len(label_freqs)), dtype=D_chunk.dtype)
#     136 for i in range(len(D_chunk)):
# --> 137     clust_dists[i] += np.bincount(
#     138         labels, weights=D_chunk[i], minlength=len(label_freqs)
#     139     )
#     141 # intra_index selects intra-cluster distances within clust_dists
#     142 intra_index = (np.arange(len(D_chunk)), labels[start : start + len(D_chunk)])
#
# File <__array_function__ internals>:200, in bincount(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# We decided to go with 7 neighbors as it starts to smoothen out after that

# %%
kmeans = KMeans(n_clusters=7, random_state=1234).fit(X_prep)
clusters = kmeans.predict(X_prep)
clusters
# Out:
# /Users/amr/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 4, 3, ..., 1, 1, 1], dtype=int32)

# %%
with open('kmeans.pkl', 'wb') as f:
    pickle.dump(kmeans, f)

# %%
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    11762
# 1    23587
# 2    21805
# 3    26062
# 4    32763
# 5     7510
# 6     1154
# dtype: int64

# %% [markdown]
# #### Transform X_prep into a df and add a clusters column to it

# %%
X_prep = pd.DataFrame(X_prep,columns=X_ft.columns)

# %%
X_prep['clusters'] = clusters

# %%
#X_prep

# %%
X_name = songs_full.select_dtypes(include=['object'])
X_name = X_name.reset_index(drop=True)

# %%
type(X_name)
type(X_prep)
# Out:
# pandas.core.frame.DataFrame

# %%
X_full = pd.concat([X_name, X_prep], axis=1)

# %%
X_full
# Out:
#                       track_id            artists  \
# 0       4u7EnebtmKWzUH433cf5Qv              Queen
# 1       21cp8L9Pei4AgysZVihjSv        Deep Purple
# 2       2g7gviEeJr6pyxO7G35EWQ          Meat Loaf
# 3       6L5BZEcZmD6RBJnimzlyKr    The Moody Blues
# 4       3gE5067onHssnwibln70ef  Aphrodite's Child
# ...                        ...                ...
# 124638  2C3TZjDRiAzdyViavDJ217      Rainy Lullaby
# 124639  1hIz5L4IB9hN3WRYPOCGPw      Rainy Lullaby
# 124640  6x8ZfSoqDjuNa5SVP5QjvX      Cesária Evora
# 124641  2e6sXL2bYv4bSz6VTdnfLs   Michael W. Smith
# 124642  2hETkH7cOfqmz3LqZDHZf5      Cesária Evora
#
#                                            track_name  duration_ms  \
# 0                 Bohemian Rhapsody - Remastered 2011     1.220776
# 1                                       Child in Time     3.755100
# 2                     Paradise By the Dashboard Light     2.693972
# 3       Nights In White Satin - Single Version / Mono     0.405680
# 4                                      Rain And Tears    -0.336729
# ...                                               ...          ...
# 124638                            Sleep My Little Boy     1.514233
# 124639                               Water Into Light     1.514242
# 124640                                 Miss Perfumado     0.428244
# 124641                                        Friends     0.547114
# 124642                                      Barbincor     0.144726
#
#         danceability    energy       key  loudness      mode  speechiness  \
# 0          -0.889074 -0.932178 -1.489627 -0.309430 -1.362868    -0.310149
# 1          -1.372502 -1.189477  1.040460 -1.293705 -1.362868    -0.437024
# 2          -1.401624  0.949319 -0.927385  0.162033  0.733747     0.393522
# 3          -2.164624 -0.614575 -0.365144  0.691262 -1.362868    -0.504366
# 4          -1.518113 -0.843732 -0.927385 -0.515163 -1.362868    -0.507294
# ...              ...       ...       ...       ...       ...          ...
# 124638     -2.298586 -1.611608 -0.084023 -1.619837  0.733747    -0.385298
# 124639     -2.286937 -2.086003 -1.489627 -2.010020 -1.362868    -0.405793
# 124640      0.363178 -1.233700 -1.489627 -0.505434 -1.362868    -0.387250
# 124641      0.118552 -0.522108  0.478219 -0.504218  0.733747    -0.507294
# 124642     -0.236738 -0.598494 -1.208506 -0.365373 -1.362868    -0.089581
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# 0          -0.151094         -0.485119  0.465188 -1.008893 -1.707097
# 1          -0.023752          1.531510  0.114962 -0.471361  0.157929
# 2          -0.323916         -0.485119  1.319527  0.012799  1.725649
# 3           0.437105          1.166058 -0.762725 -1.203320 -1.250464
# 4          -0.490673         -0.485119 -0.666679 -0.620040 -1.636110
# ...              ...               ...       ...       ...       ...
# 124638      0.967697          2.597964 -0.668801 -1.733609  0.135207
# 124639      2.041009          2.757434 -0.569570 -1.729415 -1.232709
# 124640      1.655951         -0.485119 -0.681537  0.969683  0.349443
# 124641      0.182421         -0.485119  0.305994 -0.288371  0.469668
# 124642      1.092007         -0.485119 -0.652882  0.836253 -1.435467
#
#         time_signature  clusters
# 0             0.224648         1
# 1             0.224648         0
# 2             0.224648         2
# 3             0.224648         0
# 4             0.224648         1
# ...                ...       ...
# 124638        2.572523         5
# 124639        0.224648         5
# 124640        0.224648         1
# 124641        0.224648         1
# 124642        0.224648         1
#
# [124643 rows x 17 columns]

# %%
song_cluster = X_full[['artists','track_name','clusters']]
song_cluster
# Out:
#                   artists                                     track_name  \
# 0                   Queen            Bohemian Rhapsody - Remastered 2011
# 1             Deep Purple                                  Child in Time
# 2               Meat Loaf                Paradise By the Dashboard Light
# 3         The Moody Blues  Nights In White Satin - Single Version / Mono
# 4       Aphrodite's Child                                 Rain And Tears
# ...                   ...                                            ...
# 124638      Rainy Lullaby                            Sleep My Little Boy
# 124639      Rainy Lullaby                               Water Into Light
# 124640      Cesária Evora                                 Miss Perfumado
# 124641   Michael W. Smith                                        Friends
# 124642      Cesária Evora                                      Barbincor
#
#         clusters
# 0              1
# 1              0
# 2              2
# 3              0
# 4              1
# ...          ...
# 124638         5
# 124639         5
# 124640         1
# 124641         1
# 124642         1
#
# [124643 rows x 3 columns]

# %%
song_cluster.to_csv('Song_Clusters.csv', index=False)
